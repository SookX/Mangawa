# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('exercises.json')
df
# Out:
#                                   name   force         level   mechanic  \
# 0                           3/4 Sit-Up    pull      beginner   compound
# 1                      90/90 Hamstring    push      beginner       None
# 2                    Ab Crunch Machine    pull  intermediate  isolation
# 3                            Ab Roller    pull  intermediate   compound
# 4                             Adductor  static  intermediate  isolation
# ..                                 ...     ...           ...        ...
# 868  Wrist Rotations with Straight Bar    pull      beginner  isolation
# 869                          Yoke Walk    None  intermediate   compound
# 870                     Zercher Squats    push        expert   compound
# 871                       Zottman Curl    pull  intermediate  isolation
# 872              Zottman Preacher Curl    pull  intermediate  isolation
#
#      equipment primaryMuscles  \
# 0    body only   [abdominals]
# 1    body only   [hamstrings]
# ...

# %%
df.dtypes
# Out:
# name                object
# force               object
# level               object
# mechanic            object
# equipment           object
# primaryMuscles      object
# secondaryMuscles    object
# instructions        object
# category            object
# images              object
# id                  object
# dtype: object
